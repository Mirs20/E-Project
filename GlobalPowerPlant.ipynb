# %% [markdown]
# # Global power plant

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')
df.head(5)
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.shape
# Out:
# (907, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# 1] 12 features are object data types
#
# 2] 15 variables are of float datatype

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %% [markdown]
# 1] There are lots of missinng data is found in dataset.
#
# 2] Other_fuel3 has 100% missing records.
#
# 3] weppid has 100% missing records.
#
# 4] Generation_gwh_2013 hasnot contained any records.
#
# 5] generation_gwh_2019 has 100% missing data.
#
# 6] estimated_generation_gwh has 100% missing records.

# %% [markdown]
# * Analysis of missing records

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# 1] other_fuel3,wepp_id,wepp_id, generation_gwh_2013,generation_gwh_2019,estimated_generation_gwh has all records empty.

# %%
df.isna().sum().sum()
# Out:
# 10445

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# * Number of unique values in dataset.

# %%
for i in df.columns:
    print(i,":\n")
    print(len(df[i].unique()))
    print('______________________________\n')
# Out:
# country :
#
# 1
# ______________________________
#
# country_long :
#
# 1
# ______________________________
#
# name :
#
# 907
# ______________________________
#
# gppd_idnr :
#
# 907
# ______________________________
#
# capacity_mw :
#
# 361
# ______________________________
#
# latitude :
#
# 837
# ______________________________
#
# longitude :
#
# 828
# ______________________________
#
# primary_fuel :
#
# 8
# ______________________________
#
# other_fuel1 :
#
# 4
# ______________________________
#
# other_fuel2 :
#
# 2
# ______________________________
#
# other_fuel3 :
#
# 1
# ______________________________
#
# commissioning_year :
#
# 74
# ______________________________
#
# owner :
#
# 281
# ______________________________
#
# source :
#
# 191
# ______________________________
#
# url :
#
# 304
# ______________________________
#
# geolocation_source :
#
# 4
# ______________________________
#
# wepp_id :
#
# 1
# ______________________________
#
# year_of_capacity_data :
#
# 2
# ...

# %% [markdown]
# * Unique values and their counts in datset.

# %%
for i in df.columns:
    print(i,"\n")
    print(df[i].unique())
    print('----------------------------------\n')
    print(df[i].value_counts(),'\n')
    print('----------------------------------\n')
# Out:
# country
#
# ['IND']
# ----------------------------------
#
# IND    907
# Name: country, dtype: int64
#
# ----------------------------------
#
# country_long
#
# ['India']
# ----------------------------------
#
# India    907
# Name: country_long, dtype: int64
#
# ----------------------------------
#
# name
#
# ['ACME Solar Tower' 'ADITYA CEMENT WORKS' 'AES Saurashtra Windfarms'
#  'AGARTALA GT' 'AKALTARA TPP' 'AKRIMOTA LIG' 'ALIYAR' 'ALLAIN DUHANGAN'
#  'ALMATTI DAM' 'AMAR KANTAK' 'AMARAVATI TPP' 'ANANDPUR SAHIB ST-I&II'
#  'ANAPARA "C"' 'ANDHRA' 'ANOOPGARH ST I&II' 'ANPARA' 'ANTA GT' 'ANUPPUR'
#  'ANUPUR TPP' 'ARVINDNAGAR SUGAR' 'ASHOKNAGAR MILL' 'ATHANI SUGAR'
#  'AURAIYA GT' 'AVANTHA BHANDAR TPP' 'AWARPUR CEMENT PLANT' 'Abhijeet'
#  'Amarsar Solar Power Plant' 'Anabura Wind Farm'
#  'Ananthapur - Meil Solar Power Plant' 'Andrha Lake Wind Farm'
#  'Anikkadavu Wind Farm' 'Arasinagundi Wind Farm'
#  'Askandra - DREPL Solar Power Plant'
# ...

# %% [markdown]
# * From All above analysis of missing records and unique value and value counts analysis below observations can be made,
#
# 1] country feature has only one name.
#
# 2] country_long also have country name.
#
# 3] name of power plant
#
# 4] gppd_idnr has all values are distinct for each power plant as it is id.
#
# 5] lattitude and longitude of plant location.
#
# 6] Other fuel 2 have only one datapoint with oil fuel , remaining 906 datapoints are missing or NaN.
#
# 7] Other fuel3 has no data completely missing.
#
# 8] owner feature has large amount of missing data which can be eliminated.
#
# 9] source can be removed,as it is source of data reported.
#
# 10] commissioning_year can be removed. it also has missing data.
#
# 11] url can be removed.
#
# 12] wepp_id completetly misssing data.
#
# 13] year_of_capacity_data  can be removed as it is data reporting year.
#
# 14] generation_gwh_2013 can be removed, as 100% missing records.
#
# 15] generation_gwh_2019 all values are missing.
#
# 16] generation_data_source has information about data source .can be remove.
#
# 17] estimated_generation_gwh all values are missing.
#
# 18] geolocation_source is can be removed.

# %%
eliminate= ['country','country_long','name','gppd_idnr','year_of_capacity_data','latitude','longitude','other_fuel3','other_fuel2','commissioning_year','owner','url','wepp_id','generation_gwh_2019','generation_data_source','generation_gwh_2013','estimated_generation_gwh','geolocation_source','source']

# %%
len(eliminate)
# Out:
# 19

# %%
df=df.drop(columns=eliminate,axis=1)

# %%
df.shape
# Out:
# (907, 8)

# %%
for i in df.columns:
    print(i,":\n")
    print(len(df[i].unique()))
    print('______________________________\n')
# Out:
# capacity_mw :
#
# 361
# ______________________________
#
# primary_fuel :
#
# 8
# ______________________________
#
# other_fuel1 :
#
# 4
# ______________________________
#
# generation_gwh_2014 :
#
# 372
# ______________________________
#
# generation_gwh_2015 :
#
# 397
# ______________________________
#
# generation_gwh_2016 :
#
# 404
# ______________________________
#
# generation_gwh_2017 :
#
# 409
# ______________________________
#
# generation_gwh_2018 :
#
# 411
# ______________________________

# %%
for i in df.columns:
    print(i,"\n")
    print(df[i].unique())
    print('----------------------------------\n')
    print(df[i].value_counts(),'\n')
    print('----------------------------------\n')
# Out:
# capacity_mw
#
# [2.50000e+00 9.80000e+01 3.92000e+01 1.35000e+02 1.80000e+03 2.50000e+02
#  6.00000e+01 1.92000e+02 2.90000e+02 2.10000e+02 1.35000e+03 1.34000e+02
#  1.20000e+03 1.69500e+01 9.00000e+00 2.63000e+03 4.19330e+02 6.00000e+02
#  1.00000e+01 1.70000e+01 2.40000e+01 6.52000e+02 4.60000e+01 5.00000e+01
#  1.00000e+00 1.65000e+01 1.13600e+02 1.98000e+01 1.32000e+01 5.00000e+00
#  7.05000e+02 2.80000e+01 4.50000e+02 1.80000e+02 1.05000e+03 5.10000e+02
#  6.75000e+01 3.00000e+02 3.35000e+02 1.20000e+01 3.15000e+02 3.00000e+01
#  2.00000e+01 4.20000e+01 7.20000e+02 9.00000e+01 1.32000e+03 1.20000e+02
#  6.60000e+01 2.70000e+02 2.28000e+01 1.50000e+01 2.52000e+01 1.80000e+01
#  1.70000e+03 2.60000e+01 4.10000e+01 1.37900e+03 3.40000e+01 1.60000e+01
#  5.00000e+02 8.00000e+01 7.50000e+01 1.21000e+03 9.90000e+01 6.96000e+01
#  6.00000e+00 7.50000e+02 4.00000e+01 1.65000e+02 7.00000e+01 8.15000e+01
#  1.12000e+01 3.63000e+01 1.70000e+00 2.48000e+01 5.04000e+01 1.50000e+02
# ...

# %%
df.isna().sum().sum()
# Out:
# 3102

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
plt.show()

# %%
df.isna().sum()
# Out:
# capacity_mw              0
# primary_fuel             0
# other_fuel1            709
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %% [markdown]
# * The othre fuel1 feature is data of secondary fuel used in power plant for generation in case shortage of primary fuel or for tranportation purposes. for same powerr plants it may not be applicabel as Wind solar and Water powerplants. so this values are missing . These missing values can be filled with category name Not Applicable. to fill mssing data with these i will use 'A' .
#
#
# 1] Filling missing datapoints in Other_fuel1 feature with not applicable with category "A" as it will assign 0 in LabelEncoding .

# %%
df['other_fuel1']=df['other_fuel1'].fillna('A')
df['other_fuel1'].unique()
# Out:
# array(['A', 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %% [markdown]
# * Missing records are filled with A

# %% [markdown]
# * Imputing missing records in generation features with 0

# %%
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(0)
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(0)
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(0)
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(0)
df['generation_gwh_2018']=df['generation_gwh_2018'].fillna(0)

# %% [markdown]
# * Analysing missing records after imputaion.

# %%
df.isna().sum()
# Out:
# capacity_mw            0
# primary_fuel           0
# other_fuel1            0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %% [markdown]
# * Analysing duplicate records in dataset

# %%
df[df.duplicated()]
# Out:
#      capacity_mw primary_fuel other_fuel1  generation_gwh_2014  \
# 28          50.0        Solar           A                  0.0
# 33           5.0        Solar           A                  0.0
# 34           5.0        Solar           A                  0.0
# 35           5.0        Solar           A                  0.0
# 36           5.0        Solar           A                  0.0
# ..           ...          ...         ...                  ...
# 900         16.0      Biomass           A                  0.0
# 903          3.0        Solar           A                  0.0
# 904         25.5         Wind           A                  0.0
# 905         80.0         Coal           A                  0.0
# 906         16.5         Wind           A                  0.0
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 28                   0.0                  0.0                  0.0
# 33                   0.0                  0.0                  0.0
# ...

# %% [markdown]
# * Eliminating Duplicates Records from dataset.

# %%
df.drop_duplicates(keep='first',inplace=True)

# %% [markdown]
# * feature creation with generation_gwh

# %% [markdown]
# we will add electricity generation of all years from 2014 to 2018, store this summation with new feature. which will give total generationof electricty of plant from 2014 to 2018

# %%
df['sum_generation_gwh']=df['generation_gwh_2014']+df['generation_gwh_2015']+df['generation_gwh_2016']+df['generation_gwh_2017']+df['generation_gwh_2018']

# %%
df.head()
# Out:
#    capacity_mw primary_fuel other_fuel1  generation_gwh_2014  \
# 0          2.5        Solar           A             0.000000
# 1         98.0         Coal           A             0.000000
# 2         39.2         Wind           A             0.000000
# 3        135.0          Gas           A           617.789264
# 4       1800.0         Coal         Oil          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                0.000             0.000000             0.000000
# 1                0.000             0.000000             0.000000
# 2                0.000             0.000000             0.000000
# 3              843.747           886.004428           663.774500
# 4             5916.370          6243.000000          5385.579736
#
#    generation_gwh_2018  sum_generation_gwh
# 0             0.000000            0.000000
# 1             0.000000            0.000000
# 2             0.000000            0.000000
# ...

# %%
df.shape
# Out:
# (687, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 687 entries, 0 to 902
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          687 non-null    float64
#  1   primary_fuel         687 non-null    object
#  2   other_fuel1          687 non-null    object
#  3   generation_gwh_2014  687 non-null    float64
#  4   generation_gwh_2015  687 non-null    float64
#  5   generation_gwh_2016  687 non-null    float64
#  6   generation_gwh_2017  687 non-null    float64
#  7   generation_gwh_2018  687 non-null    float64
#  8   sum_generation_gwh   687 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 53.7+ KB

# %% [markdown]
# 1] primary_fuel and other_fuel1 feature have object datatype features .
#
# 2] Remainnig features are

# %% [markdown]
# * numeric and object datatype feature sepration

# %%
cont=[]
cat=[]
for i in df.columns:
    if df[i].dtype==np.object:
        cat.append(i)
    else:
        cont.append(i)
print(len(cont))
print('Continuous   : ',cont)
print("--------------------------")
print(len(cat))
print('Categorical   : ',cat)
# Out:
# 7
# Continuous   :  ['capacity_mw', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'sum_generation_gwh']
# --------------------------
# 2
# Categorical   :  ['primary_fuel', 'other_fuel1']

# %% [markdown]
# * Distribution of nemerc features

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in cont:
    if graph<=len(cont):
        ax=plt.subplot(4,2,graph)
        sns.distplot(df[column],color='red')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# 1] All features are right skewed as impputation missing values as zero.

# %% [markdown]
# * Categorical distribution of categorical features

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in cat:
    if graph<=len(cat):
        ax=plt.subplot(2,1,graph)
        sns.countplot(df[column],color='violet')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# primary_fuel :
#
#          1] Mostly powerplants operate on Coal as primary fuel.
#
#          2] there is large number of hydro powerplants .
#
#          3] Nuclear powerplants are least in count.
#
# Other_fuel1 feature :
#
#         1] There are maximum powerplants have A category  which means that these powerplants doesn't requires other fuel or may be data have not provided.
#
#         2] Oil is used in most of powerplamnts as secondary fuel.
#
#         3] gas and energy obtained from cogeneration is used in very less powerplants.

# %% [markdown]
# * Analysing number of  powerplants on basis of Primary fuel and secondary fuels

# %%
df.groupby('other_fuel1')['primary_fuel'].value_counts()
# Out:
# other_fuel1   primary_fuel
# A             Hydro           211
#               Wind             84
#               Gas              61
#               Coal             48
#               Solar            34
#               Biomass          26
#               Oil              16
#               Nuclear           9
# Cogeneration  Coal              1
# Gas           Oil               2
# Oil           Coal            188
#               Gas               7
# Name: primary_fuel, dtype: int64

# %%
plt.figure(figsize=(10,5))
df.groupby('other_fuel1')['primary_fuel'].value_counts().plot.bar(color='cyan',width=0.1)
plt.title('primary_fuel Gropby other_fuel1 ')
plt.show()

# %% [markdown]
# 1] There is only 1 power plant where primary fuel is Coal and  other fuel used is  from cogeneration .
#
# 2] There are only 2 power plants where primary fuel used is oil while other fuel used is Gas.
#
# 3] There are only 188 power plants where primary fuel used is coal while other fuel used is oil.
#
# 4] There are only 7 power plants where primary fuel used is Gas while other fuel used is oil.
#
# 5] hydro solar wind coal gas biomass oil and nuclear where other fuels are not used or there data isnot available.

# %% [markdown]
# * Mean capacity of powerplants on basis of primary fuel of operation.

# %%
df.groupby('primary_fuel')['capacity_mw'].mean()
# Out:
# primary_fuel
# Biomass     21.417692
# Coal       862.384895
# Gas        369.080971
# Hydro      218.022133
# Nuclear    975.555556
# Oil         96.202222
# Solar       45.423529
# Wind        36.892857
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['capacity_mw'].mean().plot.bar(color='cyan',width=0.1)
plt.title('capacity_mw Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] The Highest mean capacity of power plants with nuclear fuel is 976.55mW.
#
# 2] The mean capacity of power plants with coal fuel is 797.82 mW.
#
# 3] The mean capacity of power plants with Gas fuel is 364.81 mW.
#
# 4] The mean capacity of power plants with Hydro fuel which works on water in reservior  is 218.02 mW.
#
# 5] The mean capacity of power plants with Oil fuel is 88.942000 mW.
#
# 6] the mean capacities for solar wind and biomass are 22.53 36.89 20.065 mW respectively.

# %% [markdown]
# * Total generation of electricity in 2014 by primary fuel.

# %%
df.groupby('primary_fuel')['generation_gwh_2014'].sum()
# Out:
# primary_fuel
# Biomass         0.000000
# Coal       762701.968920
# Gas         40099.876382
# Hydro      129551.355420
# Nuclear     34072.893150
# Oil          1439.695026
# Solar           0.000000
# Wind            0.000000
# Name: generation_gwh_2014, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['generation_gwh_2014'].sum().plot.bar(color='cyan',width=0.1)
plt.title('generation_gwh_2014 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity in 2014 in power plants operated on Coal is 762701.968 gigaWatts. which highest of all fuel type.
#
# 2] Total Generation of electricity in 2014 in power plants operated on Hydro is 129551.35 gigaWatts.
#
# 3] Total Generation of electricity in 2014 in power plants operated on Gas is 40099.87 gigaWatts.
#
# 4] Total Generation of electricity in 2014 in power plants operated on Nuclear is 34072.89 gigaWatts.
#
# 5] Total Generation of electricity in 2014 in power plants operated on Oil is 1439.69 gigaWatts.

# %% [markdown]
# * Total generation of electricity in 2015 by primary fuel.

# %%
df.groupby('primary_fuel')['generation_gwh_2015'].sum()
# Out:
# primary_fuel
# Biomass         0.000000
# Coal       822976.677975
# Gas         46208.780652
# Hydro      121408.501625
# Nuclear     33879.000000
# Oil           238.810943
# Solar           0.000000
# Wind            0.000000
# Name: generation_gwh_2015, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['generation_gwh_2015'].sum().plot.bar(color='lightgreen',width=0.1)
plt.title('Total generation_gwh_2015 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity in 2015 in power plants operated on Coal is 822976.677 gigaWatts, which has increase from last year 2014.
#
# 2] Total Generation of electricity in 2015 in power plants operated on Hydro is 121408.50 gigaWatts, which has decreased from last year generation.
#
# 3] Total Generation of electricity in 2015 in power plants operated on Gas is 46208.780 gigaWatts, which has increase from last year geneartion.
#
# 4] Total Generation of electricity in 2015 in power plants operated on Nuclear is 33879.0 gigaWatts,which has decreased from last year generation.
#
# 5] Total Generation of electricity in 2015 in power plants operated on Oil is 238.8 gigaWatts which has been decreased to 90%.

# %% [markdown]
# * Total generation of electricity in 2016 by primary fuel.

# %%
df.groupby('primary_fuel')['generation_gwh_2016'].sum()
# Out:
# primary_fuel
# Biomass         0.000000
# Coal       866544.578110
# Gas         47925.719163
# Hydro      122380.663790
# Nuclear     34180.870000
# Oil            52.765584
# Solar           0.000000
# Wind            0.000000
# Name: generation_gwh_2016, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['generation_gwh_2016'].sum().plot.bar(color='brown',width=0.1)
plt.title('Total generation_gwh_2016 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity in 2016 in power plants operated on Coal is 866544.57 gigaWatts, which has increase from last year 2014.
#
# 2] Total Generation of electricity in 2016 in power plants operated on Hydro is 122380.66 gigaWatts, which has decreased from last year generation.
#
# 3] Total Generation of electricity in 2016 in power plants operated on Gas is 47925.71 gigaWatts, which has increase from last year geneartion.
#
# 4] Total Generation of electricity in 2016 in power plants operated on Nuclear is 34180.87 gigaWatts,which has increased from last year generation.
#
# 5] Total Generation of electricity in 2016 in power plants operated on Oil is 52.765 gigaWatts which is decreasing in upcomimng year.

# %% [markdown]
# * Total generation of electricity in 2017 by primary fuel.

# %%
df.groupby('primary_fuel')['generation_gwh_2017'].sum()
# Out:
# primary_fuel
# Biomass         0.000000
# Coal       910790.472360
# Gas         49348.106481
# Hydro      126287.022845
# Nuclear     34587.320000
# Oil             1.172299
# Solar           0.000000
# Wind            0.000000
# Name: generation_gwh_2017, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['generation_gwh_2017'].sum().plot.bar(color='r',width=0.1)
plt.title('Total generation_gwh_2017 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity in 2017 in power plants operated on Coal is 910790.472 gigaWatts,
#
# 2] Total Generation of electricity in 2017 in power plants operated on Hydro is 126287.02 gigaWatts.
#
# 3] Total Generation of electricity in 2017 in power plants operated on Gas is 49348.10 gigaWatts.
#
# 4] Total Generation of electricity in 2017 in power plants operated on Nuclear is 34587.32 gigaWatts.
#
# 5] Total Generation of electricity in 2017 in power plants operated on Oil is 1.17 gigaWatts.

# %% [markdown]
# * Total generation of electricity in 2018 by primary fuel.

# %%
df.groupby('primary_fuel')['generation_gwh_2018'].sum()
# Out:
# primary_fuel
# Biomass         0.000000
# Coal       946847.079336
# Gas         49106.188266
# Hydro      134987.471238
# Nuclear     34216.250000
# Oil             3.247360
# Solar           0.000000
# Wind            0.000000
# Name: generation_gwh_2018, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['generation_gwh_2018'].sum().plot.bar(color='r',width=0.1)
plt.title('Total generation_gwh_2018 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity in 2017 in power plants operated on Coal is 946847.079 gigaWatts,
#
# 2] Total Generation of electricity in 2017 in power plants operated on Hydro is 134987.47 gigaWatts.
#
# 3] Total Generation of electricity in 2017 in power plants operated on Gas is 49106.18 gigaWatts.
#
# 4] Total Generation of electricity in 2017 in power plants operated on Nuclear is 34216.25 gigaWatts.
#
# 5] Total Generation of electricity in 2017 in power plants operated on Oil is 3.24 gigaWatts.

# %% [markdown]
# * Total generation of electricity from 2014 to 2018 by primary fuel.

# %%
df.groupby('primary_fuel')['sum_generation_gwh'].sum()
# Out:
# primary_fuel
# Biomass    0.000000e+00
# Coal       4.309861e+06
# Gas        2.326887e+05
# Hydro      6.346150e+05
# Nuclear    1.709363e+05
# Oil        1.735691e+03
# Solar      0.000000e+00
# Wind       0.000000e+00
# Name: sum_generation_gwh, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['sum_generation_gwh'].sum().plot.bar(color='r',width=0.1)
plt.title('Total generation of electricity i all years from 2014 to 2018 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] Total Generation of electricity  from 2014-2018 in power plants operated on Coal is 4.309861e+06 gigaWatts,
#
# 2] Total Generation of electricity  from 2014-2018  in power plants operated on Hydro is 6.346150e+05 gigaWatts.
#
# 3] Total Generation of electricity  from 2014-2018  in power plants operated on Gas is 2.326887e+05 gigaWatts.
#
# 4] Total Generation of electricity  from 2014-2018  in power plants operated on Nuclear is 1.709363e+05 gigaWatts.
#
# 5] Total Generation of electricity  from 2014-2018  in power plants operated on Oil is  1.735691e+03 gigaWatts.

# %% [markdown]
# * Mean generation of electricty of  total generation from 2014 to 2018 by primary fuel.

# %%
df.groupby('primary_fuel')['sum_generation_gwh'].mean()
# Out:
# primary_fuel
# Biomass        0.000000
# Coal       18185.066568
# Gas         3421.892220
# Hydro       3007.654099
# Nuclear    18992.925906
# Oil           96.427290
# Solar          0.000000
# Wind           0.000000
# Name: sum_generation_gwh, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('primary_fuel')['sum_generation_gwh'].mean().plot.bar(color='skyblue',width=0.1)
plt.title('Total generation of electricity i all years from 2014 to 2018 Gropby primary_fuel ')
plt.show()

# %% [markdown]
# 1] mean Generation of sum of  electricity  from 2014-2018 in each  power plants operated on Coal is 16704.88 gigaWatts,
#
# 2] mean Generation of sum of  electricity  from 2014-2018 in each  power plants operated on Nuclear fuel  is 18992.93 gigaWatts. Nuclear Power plants have higher electricity generation rate.
#
#
# 3] mean Generation of sum of  electricity  from 2014-2018 in each  power plants operated on Gas fuel is 3372.299 gigaWatts,
#
#
# 4] mean Generation of sum of  electricity  from 2014-2018 in each  power plants operated on Hydro is 3007.65 gigaWatts, Gas and Hydro poweplants have same generation rate.
#
#
# 5] mean Generation of sum of  electricity  from 2014-2018 in each  power plants operated on Oil fuel is 86.784  gigaWatts,

# %% [markdown]
# * Categorical featue vs Capacity_mw target

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in cat:
    if graph<=2:
        ax=plt.subplot(2,1,graph)
        sns.swarmplot(x=df[column],y=df['capacity_mw'])
        plt.xlabel(column,fontsize=15)
        plt.xticks(fontsize=12)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# Primary fuel with capacity_mw :
#
#     1] Highest capacity plants are of Coal as promary fuel.
#
#     2] Nuclear,gas and Hydro plants have mediaum capacity upto 2500 mW.
#
#     3] Solar Wind Oil and Biomass have lowest capacities.
#
#
# higher capacities are mostly depends on primary fuel, Its missleading to define capacitoes on basis of only secodary fuel.

# %% [markdown]
# * continuous feature analysis with target capacity_mw

# %%
plt.figure(figsize=(20,20))
sns.set_palette('bright')
graph=1

for column in cont:
    if graph<=7:
        ax=plt.subplot(4,2,graph)
        sns.scatterplot(y=df[column],x=df['capacity_mw'])
        plt.ylabel(column,fontsize=15)
        plt.xticks(fontsize=12)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# 1] There is strong relation between features and capacity_mw  as all grapghs have same trend.

# %% [markdown]
# * Features analyssis with primary Fuel.

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in df.columns:
    if graph<=9:
        ax=plt.subplot(5,2,graph)
        sns.swarmplot(x=df[column],y=df['primary_fuel'])
        plt.xlabel(column,fontsize=15)
        plt.xticks(fontsize=12)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# 1] Electricity Generation  is highest for coal opearated plants in every year from 2014 to 2018
#
# 2] Electricity generation for Hydro and Gas plants is same in  all years.
#
# 3] Electricity generation for nuclear plants higher than Gas and Hydro but lower than Coal.

# %% [markdown]
# * Encoding variables

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['primary_fuel']=le.fit_transform(df['primary_fuel'])
df['other_fuel1']=le.fit_transform(df['other_fuel1'])

# %% [markdown]
# # Regression with capacity _mw as target

# %%
DF=df.copy()
DF.head()
# Out:
#    capacity_mw  primary_fuel  other_fuel1  generation_gwh_2014  \
# 0          2.5             6            0             0.000000
# 1         98.0             1            0             0.000000
# 2         39.2             7            0             0.000000
# 3        135.0             2            0           617.789264
# 4       1800.0             1            3          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                0.000             0.000000             0.000000
# 1                0.000             0.000000             0.000000
# 2                0.000             0.000000             0.000000
# 3              843.747           886.004428           663.774500
# 4             5916.370          6243.000000          5385.579736
#
#    generation_gwh_2018  sum_generation_gwh
# 0             0.000000            0.000000
# 1             0.000000            0.000000
# 2             0.000000            0.000000
# ...

# %%
DF.shape
# Out:
# (687, 9)

# %% [markdown]
# * Dataset hs 687 rows or datapoints. Dataset consist of 9 variables out of which 8 are features and capacity_mw is target feature which continuous in nature.

# %% [markdown]
# * 1] Continuous or infinite  feature in regression task excludes capacity_mw which is target.

# %%
inf1=cont[1:]
inf1
# Out:
# ['generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'sum_generation_gwh']

# %% [markdown]
# * Analysis of distribution Continuous variables.

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in inf1:
    if graph<=len(inf1):
        ax=plt.subplot(3,2,graph)
        sns.distplot(DF[column],color='red')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# 1] All features are right skewed.

# %% [markdown]
# * Outliers detection in infinite variables in Regression task.

# %%
plt.figure(figsize=(20,15))
sns.set_palette('bright')
graph=1

for column in inf1:
    if graph<=6:
        ax=plt.subplot(3,2,graph)
        sns.violinplot(y=DF[column])
        plt.ylabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# 1] All features are right skewed in nature. Having outliers in high side.

# %% [markdown]
# * Outliers detection with Boxplot

# %%
plt.figure(figsize=(20,15))
sns.set_palette('bright')
graph=1

for column in inf1:
    if graph<=6:
        ax=plt.subplot(3,2,graph)
        sns.boxplot(y=DF[column])
        plt.ylabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Analyse outliers removal and data loss

# %%
DaF=DF.copy()
rows_before1=DaF.shape[0]
rows_before1
# Out:
# 687

# %%
from scipy.stats import zscore

z1=np.abs(zscore(DaF[inf1]))
DaF=DaF[(z1<3).all(axis=1)]

# %%
rows_after1=DaF.shape[0]
rows_after1
# Out:
# 670

# %%
loss1=((rows_before1-rows_after1)/rows_before1)*100
loss1
# Out:
# 2.4745269286754

# %% [markdown]
# * Data Loss after removal of outliers is 2.474 % so it can be safe to remove outliers with
#   z score method

# %% [markdown]
# * Analysis of Distribution of continuous feature before and after outliers removal

# %%
plt.figure(figsize=(20,20))
sns.set_palette('bright')
graph=1

for column in inf1:
    if graph<=len(inf1):
        ax=plt.subplot(3,2,graph)
        sns.kdeplot(DF[column],color='red',shade=True)
        sns.kdeplot(DaF[column],color='green',shade=True)
        plt.xlabel(column,fontsize=20)
        plt.title("Distribution of {} Before and After Outlier treatment ".format(column))
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Lets remove outliers with zscore

# %%
# shape of dataset before outliers removal
DF.shape
# Out:
# (687, 9)

# %%
zscr=np.abs(zscore(DF[inf1]))
DF=DF[(zscr<3).all(axis=1)]

# %%
DF.shape
# Out:
# (670, 9)

# %% [markdown]
# * Correlation Analysis of variables

# %%
cor1=DF.corr().abs()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor1,annot=True)
plt.title("Correlation Matrix for regression")
plt.show()

# %% [markdown]
# 1] There is high rate in yearly electricity generations with each other.
#
# 2] the sum_generation_gwh is feature created with addition of yearly generation hence very strong and high correlation with these features .
#
# 3] Other fuel1 feature has moderate corrleation with yearly Generation features.
#
# 4] Primary fuel has correlation with with all other feature which is in range of 0.3 to 0.4 .

# %%
cor_target=(DF.drop('capacity_mw',axis=1)).corrwith(DF['capacity_mw']).abs()
cor_target
# Out:
# primary_fuel           0.391939
# other_fuel1            0.608084
# generation_gwh_2014    0.647677
# generation_gwh_2015    0.708705
# generation_gwh_2016    0.782977
# generation_gwh_2017    0.831686
# generation_gwh_2018    0.852585
# sum_generation_gwh     0.810989
# dtype: float64

# %%
plt.figure(figsize=(10,10))
cor_target.plot(kind="bar",color='lightgreen')
plt.title("Correlation with  target capacity_mw")
plt.show()

# %% [markdown]
# 1] Yearly Generation features have more than 0.6 correlation with capacity_mw
#
# 2] sum_generation_gw have 0.81 correlation with capacity_mw
#
# 3] Praimary fuel have very less 0.39 correlation with capacity_mw.

# %% [markdown]
# * Analyse Multicollinearity with Variance Inflation Factor,Threshold for vif score is defined as 5 as data is less

# %%
from statsmodels.stats.outliers_influence  import variance_inflation_factor

Predictors1=DF.drop(columns=['capacity_mw'],axis=1)
predictor1=Predictors1.to_numpy()

# %%
VIF1=pd.DataFrame()
VIF1["Features"]=Predictors1.columns
VIF1["vif_scores"]=[variance_inflation_factor(predictor1,i) for i in range(Predictors1.shape[1])]
VIF1
# Out:
#               Features  vif_scores
# 0         primary_fuel    1.052943
# 1          other_fuel1    2.100146
# 2  generation_gwh_2014         inf
# 3  generation_gwh_2015         inf
# 4  generation_gwh_2016         inf
# 5  generation_gwh_2017         inf
# 6  generation_gwh_2018         inf
# 7   sum_generation_gwh         inf

# %% [markdown]
# * Lets remove created feature with to analyse weather the infinite value multicollinearity due to calculated feature or not.

# %% [markdown]
# * Analyse vif score after eliminating sum_generation_gwh

# %%
Predictors2=DF.drop(columns=['capacity_mw','sum_generation_gwh'],axis=1)
predictor2=Predictors2.to_numpy()
VIF2=pd.DataFrame()
VIF2["Features"]=Predictors2.columns
VIF2["vif_scores"]=[variance_inflation_factor(predictor2,i) for i in range(Predictors2.shape[1])]
VIF2
# Out:
#               Features  vif_scores
# 0         primary_fuel    1.052943
# 1          other_fuel1    2.100146
# 2  generation_gwh_2014    9.821265
# 3  generation_gwh_2015   21.006625
# 4  generation_gwh_2016   22.973425
# 5  generation_gwh_2017   30.984863
# 6  generation_gwh_2018   21.462912

# %% [markdown]
# * Although infinite value of multicllinearity is due to created feature but remaing features also have high amount of multicollinearity which will analyse after removing some feature to reduce below threshold 10 vif score .

# %% [markdown]
# * Analyse vif score after removal of generation_gwh_2017

# %%
Predictors3=DF.drop(columns=['capacity_mw','sum_generation_gwh','generation_gwh_2017'],axis=1)
predictor3=Predictors3.to_numpy()
VIF3=pd.DataFrame()
VIF3["Features"]=Predictors3.columns
VIF3["vif_scores"]=[variance_inflation_factor(predictor3,i) for i in range(Predictors3.shape[1])]
VIF3
# Out:
#               Features  vif_scores
# 0         primary_fuel    1.052852
# 1          other_fuel1    2.084019
# 2  generation_gwh_2014    9.792760
# 3  generation_gwh_2015   20.759762
# 4  generation_gwh_2016   17.921885
# 5  generation_gwh_2018    9.014262

# %% [markdown]
# * Analyse vif score after removal of generation_gwh_2015

# %%
Predictors4=DF.drop(columns=['capacity_mw','sum_generation_gwh','generation_gwh_2017','generation_gwh_2015'],axis=1)
predictor4=Predictors4.to_numpy()
VIF4=pd.DataFrame()
VIF4["Features"]=Predictors4.columns
VIF4["vif_scores"]=[variance_inflation_factor(predictor4,i) for i in range(Predictors4.shape[1])]
VIF4
# Out:
#               Features  vif_scores
# 0         primary_fuel    1.052807
# 1          other_fuel1    2.079945
# 2  generation_gwh_2014    4.120482
# 3  generation_gwh_2016   11.626181
# 4  generation_gwh_2018    8.884231

# %% [markdown]
# * Analyse vif score after removal of generation_gwh_2016

# %%
Predictors5=DF.drop(columns=['capacity_mw','sum_generation_gwh','generation_gwh_2017','generation_gwh_2015','generation_gwh_2016'],axis=1)
predictor5=Predictors5.to_numpy()
VIF5=pd.DataFrame()
VIF5["Features"]=Predictors5.columns
VIF5["vif_scores"]=[variance_inflation_factor(predictor5,i) for i in range(Predictors5.shape[1])]
VIF5
# Out:
#               Features  vif_scores
# 0         primary_fuel    1.052806
# 1          other_fuel1    2.075982
# 2  generation_gwh_2014    2.995725
# 3  generation_gwh_2018    3.623917

# %% [markdown]
# 1]  To remove multicollinearity from feature It is required to remove 3 features and 01 created feature  out of 7 features  which is 40 % hence we will find another approach for handling multicollinearity
#
# 2] Also generation_gwh_2017 generation_gwh_2015,generation_gwh_2016  features have 0.71 and 0.83 ,0.78 correlation with target feature capacity_mw.

# %% [markdown]
# * Analysis for Skewness in  continuous features features.

# %%
DF[inf1].skew()
# Out:
# generation_gwh_2014    2.397590
# generation_gwh_2015    2.225520
# generation_gwh_2016    2.154973
# generation_gwh_2017    2.033200
# generation_gwh_2018    2.091103
# sum_generation_gwh     2.027484
# dtype: float64

# %%
DF[inf1].skew().plot.bar(color='pink')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Analysis with various transformation to remove skewness in dataset.

# %%
DaF=DF.copy()

# %% [markdown]
# 1] Power Transformation with yeo-johnson method .

# %%
from sklearn.preprocessing import PowerTransformer

# %%
transform1=pd.DataFrame()
pwr1=PowerTransformer(method='yeo-johnson')
transform1[inf1]=pwr1.fit_transform(DaF[inf1])
transform1[inf1].skew()
# Out:
# generation_gwh_2014    0.104967
# generation_gwh_2015    0.047289
# generation_gwh_2016    0.013635
# generation_gwh_2017    0.000365
# generation_gwh_2018   -0.016646
# sum_generation_gwh    -0.125217
# dtype: float64

# %% [markdown]
# * Sqaure root transformation

# %%
transform2=pd.DataFrame()
transform2=np.sqrt(DaF[inf1])
transform2.skew()
# Out:
# generation_gwh_2014    1.277914
# generation_gwh_2015    1.207194
# generation_gwh_2016    1.162777
# generation_gwh_2017    1.117984
# generation_gwh_2018    1.131548
# sum_generation_gwh     1.070726
# dtype: float64

# %% [markdown]
# * Cuberoot transformation

# %%
transform3=pd.DataFrame()
transform3=np.cbrt(DaF[inf1])
transform3.skew()
# Out:
# generation_gwh_2014    0.763559
# generation_gwh_2015    0.714786
# generation_gwh_2016    0.675507
# generation_gwh_2017    0.645599
# generation_gwh_2018    0.637996
# sum_generation_gwh     0.573792
# dtype: float64

# %% [markdown]
# * log transformation

# %%
transform4=pd.DataFrame()
transform4=np.log(DaF[inf1])
transform4.skew()
# Out:
# generation_gwh_2014   NaN
# generation_gwh_2015   NaN
# generation_gwh_2016   NaN
# generation_gwh_2017   NaN
# generation_gwh_2018   NaN
# sum_generation_gwh    NaN
# dtype: float64

# %% [markdown]
# * Quantile Transformation

# %%
from sklearn.preprocessing import QuantileTransformer
qt1=QuantileTransformer(n_quantiles=100,output_distribution='normal')

transform5=pd.DataFrame()
transform5[inf1]=qt1.fit_transform(DaF[inf1])
transform5[inf1].skew()
# Out:
# generation_gwh_2014   -0.025592
# generation_gwh_2015   -0.166655
# generation_gwh_2016   -0.217188
# generation_gwh_2017   -0.240580
# generation_gwh_2018   -0.246151
# sum_generation_gwh    -0.371936
# dtype: float64

# %% [markdown]
# * Out of all above transformation PowerTransformer works betterr.
#
# Lets transform original dataframe with PowerTransformer

# %%
power1=PowerTransformer(method='yeo-johnson')

DF[inf1]=power1.fit_transform(DF[inf1])

# %% [markdown]
# * Analyse skewness after transformation.

# %%
DF[inf1].skew()
# Out:
# generation_gwh_2014    0.104967
# generation_gwh_2015    0.047289
# generation_gwh_2016    0.013635
# generation_gwh_2017    0.000365
# generation_gwh_2018   -0.016646
# sum_generation_gwh    -0.125217
# dtype: float64

# %%
fig,axs=plt.subplots(1,2)
DaF[inf1].skew().plot.bar(ax=axs[0],color='pink',title='Before')
DF[inf1].skew().plot.bar(ax=axs[1],color='lightgreen',title='After')
plt.yticks(np.arange(-0.5,2.5,0.5))
plt.show()

# %% [markdown]
# * Skewness has been removed from features can be observed from graph

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in inf1:
    if graph<=len(inf1):
        ax=plt.subplot(3,2,graph)
        sns.distplot(DaF[column],color='red')
        sns.distplot(DF[column],color='green')
        plt.xlabel(column,fontsize=20)
        plt.legend(['Before Transformation','After Transformation'])
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Splitting dataset into feature and target

# %%
x=DF.drop('capacity_mw',axis=1)
y=DF.capacity_mw

# %%
print('x shape is ',x.shape)
print('y shape is ',y.shape)
# Out:
# x shape is  (670, 8)
# y shape is  (670,)

# %% [markdown]
# * Standadization of features.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled1=scaler.fit_transform(x)

# %%
x_scaled1.shape
# Out:
# (670, 8)

# %% [markdown]
# * Principal Component Analysis to handle high amount of multicollinearity.

# %%
from sklearn.decomposition import PCA

pcr=PCA()
pcr.fit_transform(x_scaled1)
# Out:
# array([[-3.01575973, -0.55494809,  0.66259236, ..., -0.02970261,
#         -0.03837535, -0.00779448],
#        [-2.47328258,  1.12901433, -0.96491579, ..., -0.05214651,
#         -0.08227977, -0.01277329],
#        [-3.12425516, -0.89174057,  0.98809399, ..., -0.02521383,
#         -0.02959446, -0.00679872],
#        ...,
#        [ 3.39667021,  0.63142586,  0.47743018, ..., -0.01218122,
#         -0.08772698, -0.02074345],
#        [-2.9072643 , -0.2181556 ,  0.33709073, ..., -0.03419139,
#         -0.04715623, -0.00879024],
#        [ 0.92564837,  1.80290123,  0.85837935, ..., -0.31090865,
#          0.25564495,  0.04960984]])

# %%
plt.figure()
plt.plot(np.cumsum(pcr.explained_variance_ratio_))
plt.xlabel('Components')
plt.ylabel('Variance Explained')
plt.title('PCA analysis')
plt.xticks(range(0,8))
plt.show()

# %%
pd.Series(np.cumsum(pcr.explained_variance_ratio_))
# Out:
# 0    0.766077
# 1    0.885059
# 2    0.945401
# 3    0.978558
# 4    0.989156
# 5    0.994271
# 6    0.997686
# 7    1.000000
# dtype: float64

# %% [markdown]
# * The 99.5 % variance in data can be explained with 6 components hence we will applying these features for model building.

# %%
pcr1=PCA(n_components=6)
dimR=pcr1.fit_transform(x_scaled1)
x_dimR=pd.DataFrame(dimR,columns=[('PC{}').format(i) for i in range(1,7)])
x_dimR
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6
# 0   -3.015760 -0.554948  0.662592 -0.042283  0.020404 -0.029703
# 1   -2.473283  1.129014 -0.964916 -0.045442  0.004501 -0.052147
# 2   -3.124255 -0.891741  0.988094 -0.041651  0.023585 -0.025214
# 3    1.770808 -0.760858 -0.797745  0.041867  0.078646 -0.053419
# 4    3.739187  0.537872  0.493600 -0.167268  0.011271  0.018062
# ..        ...       ...       ...       ...       ...       ...
# 665 -3.124255 -0.891741  0.988094 -0.041651  0.023585 -0.025214
# 666 -3.124255 -0.891741  0.988094 -0.041651  0.023585 -0.025214
# 667  3.396670  0.631426  0.477430 -0.353358 -0.038275 -0.012181
# 668 -2.907264 -0.218156  0.337091 -0.042915  0.017224 -0.034191
# 669  0.925648  1.802901  0.858379  1.389097 -0.162532 -0.310909
#
# [670 rows x 6 columns]

# %% [markdown]
# * Datset with component

# %%
x_dimR.shape
# Out:
# (670, 6)

# %%
y.shape
# Out:
# (670,)

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor


from sklearn.metrics import mean_squared_error ,mean_absolute_error,r2_score 
from sklearn.model_selection import cross_val_score

# %% [markdown]
# * spliting dataset into train test set

# %%
maxR2=0
maxRn=0
for i  in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x_dimR,y,test_size=0.20,random_state=i)
    regr=LinearRegression()
    regr.fit(x_train,y_train)
    r2=regr.score(x_test,y_test)
    print("R squared ",r2,'Random sate ',i)
    
    if r2>maxR2:
        maxR2=r2
        maxRn=i
        print("R-squared",maxR2,"random_state",i)
# Out:
# R squared  0.5265395461272396 Random sate  1
# R-squared 0.5265395461272396 random_state 1
# R squared  0.4220959198583719 Random sate  2
# R squared  0.5993292832804411 Random sate  3
# R-squared 0.5993292832804411 random_state 3
# R squared  0.6216490420115821 Random sate  4
# R-squared 0.6216490420115821 random_state 4
# R squared  0.37470141584733374 Random sate  5
# R squared  0.5625531299464952 Random sate  6
# R squared  0.5323607541576856 Random sate  7
# R squared  0.4892573779606022 Random sate  8
# R squared  0.5303876406806709 Random sate  9
# R squared  0.5575292336195504 Random sate  10
# R squared  0.5126984481077572 Random sate  11
# R squared  0.4684296871821422 Random sate  12
# R squared  0.5572588882974179 Random sate  13
# R squared  0.5978588088015042 Random sate  14
# R squared  0.5147424172553978 Random sate  15
# R squared  0.6131194467419612 Random sate  16
# R squared  0.5509170176717041 Random sate  17
# R squared  0.6344274236878207 Random sate  18
# ...

# %%
print("Maximum R squared obtained  is ",maxR2,'at random state',maxRn)
# Out:
# Maximum R squared obtained  is  0.656187715404084 at random state 28

# %% [markdown]
# * Train Teat split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_dimR,y,test_size=0.20,random_state=28)

# %% [markdown]
# * Function for evaluation in Regression

# %%
def Reg_eval(regr,x_train,y_train,x_test,y_test,train=True):
    if train==True:
        print('********** Training Evaluation *******************')
        ytrain_pred=regr.predict(x_train)
        
        R2_train=r2_score(y_train,ytrain_pred)
       
        RMSE_train=np.sqrt(mean_squared_error(y_train,ytrain_pred))
        print("\nThe R squared for {0}  for Train data  is {1} ".format(str(regr),R2_train))
        print("\nThe Root mean squared error for {0}  for Train data is {1} ".format(str(regr),RMSE_train))
        
        
        
    elif train==False:
        print('\n********** Testing  Evaluation *******************')
        ytest_pred=regr.predict(x_test)
        R2_test=r2_score(y_test,ytest_pred)
        RMSE_test=np.sqrt(mean_squared_error(y_test,ytest_pred))
        print(" \nThe R squared for {0}  for Test data is {1} ".format(str(regr),R2_test))
        print("\nThe Root mean squared error for {0}  Test data  is {1} ".format(str(regr),RMSE_test))

def Reg_plot(regr,x_test,y_test):
    y_pred_test=regr.predict(x_test)
    plt.figure(figsize=(10,10))
    
    sns.scatterplot(x=y_test,y=y_pred_test)
    plt.plot(y_test,y_test,color='red')
    plt.xlabel("Actual Sales")
    plt.ylabel("Predicted sales")
    plt.title("{} Prediction VS Actual data".format(type(regr)))
    plt.show()

# %% [markdown]
# * Linear Regression

# %%
LinR1=LinearRegression()
LinR1.fit(x_train,y_train)

Reg_eval(LinR1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(LinR1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for LinearRegression()  for Train data  is 0.5088718501839593
#
# The Root mean squared error for LinearRegression()  for Train data is 339.41113144225545
#
# ********** Testing  Evaluation *******************
#
# The R squared for LinearRegression()  for Test data is 0.656187715404084
#
# The Root mean squared error for LinearRegression()  Test data  is 301.29713964295433

# %% [markdown]
# * Lasso regression

# %%
las1=Lasso(alpha=0.1)
las1.fit(x_train,y_train)

Reg_eval(las1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(las1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for Lasso(alpha=0.1)  for Train data  is 0.5088699011923534
#
# The Root mean squared error for Lasso(alpha=0.1)  for Train data is 339.41180490069
#
# ********** Testing  Evaluation *******************
#
# The R squared for Lasso(alpha=0.1)  for Test data is 0.6560719280745917
#
# The Root mean squared error for Lasso(alpha=0.1)  Test data  is 301.34787002116593

# %% [markdown]
# * Ridge Regression

# %%
rid1=Ridge(alpha=0.1)
rid1.fit(x_train,y_train)

Reg_eval(rid1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(rid1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for Ridge(alpha=0.1)  for Train data  is 0.5088717742755678
#
# The Root mean squared error for Ridge(alpha=0.1)  for Train data is 339.411157671817
#
# ********** Testing  Evaluation *******************
#
# The R squared for Ridge(alpha=0.1)  for Test data is 0.6561705376369111
#
# The Root mean squared error for Ridge(alpha=0.1)  Test data  is 301.30466634822545

# %% [markdown]
# * Support Vector Regression

# %%
SVR1=SVR(gamma=0.3,C=100,kernel='rbf')
SVR1.fit(x_train,y_train)

Reg_eval(SVR1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(SVR1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for SVR(C=100, gamma=0.3)  for Train data  is 0.6647431950588412
#
# The Root mean squared error for SVR(C=100, gamma=0.3)  for Train data is 280.42547798840644
#
# ********** Testing  Evaluation *******************
#
# The R squared for SVR(C=100, gamma=0.3)  for Test data is 0.7652822879328295
#
# The Root mean squared error for SVR(C=100, gamma=0.3)  Test data  is 248.94719957277624

# %% [markdown]
# * RandomForest Regressor

# %%
rf1=RandomForestRegressor(criterion='squared_error',min_samples_leaf=14,min_samples_split=18,n_estimators=100,max_depth=11,random_state=10)
rf1.fit(x_train,y_train)

Reg_eval(rf1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(rf1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for RandomForestRegressor(max_depth=11, min_samples_leaf=14, min_samples_split=18,
#                       random_state=10)  for Train data  is 0.7335258328829146
#
# The Root mean squared error for RandomForestRegressor(max_depth=11, min_samples_leaf=14, min_samples_split=18,
#                       random_state=10)  for Train data is 250.00933483820168
#
# ********** Testing  Evaluation *******************
#
# The R squared for RandomForestRegressor(max_depth=11, min_samples_leaf=14, min_samples_split=18,
#                       random_state=10)  for Test data is 0.750608305552759
#
# The Root mean squared error for RandomForestRegressor(max_depth=11, min_samples_leaf=14, min_samples_split=18,
#                       random_state=10)  Test data  is 256.6110221669512

# %% [markdown]
# * XGB Regressor

# %%
xgr1=XGBRegressor(learning_rate=0.15,n_estimators=100,random_state=45)
xgr1.fit(x_train,y_train)

Reg_eval(xgr1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(xgr1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.15, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=45,
#              reg_alpha=0, reg_lambda=1, ...)  for Train data  is 0.9657698239415192
#
# The Root mean squared error for XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
# ...

# %% [markdown]
# * DecisionTreeRegressor

# %%
dt1=DecisionTreeRegressor(min_samples_split=7,min_samples_leaf=26,random_state=17,max_depth=11)
dt1.fit(x_train,y_train)

Reg_eval(dt1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(dt1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for DecisionTreeRegressor(max_depth=11, min_samples_leaf=26, min_samples_split=7,
#                       random_state=17)  for Train data  is 0.6843304499379717
#
# The Root mean squared error for DecisionTreeRegressor(max_depth=11, min_samples_leaf=26, min_samples_split=7,
#                       random_state=17)  for Train data is 272.11032029908296
#
# ********** Testing  Evaluation *******************
#
# The R squared for DecisionTreeRegressor(max_depth=11, min_samples_leaf=26, min_samples_split=7,
#                       random_state=17)  for Test data is 0.7251295606631691
#
# The Root mean squared error for DecisionTreeRegressor(max_depth=11, min_samples_leaf=26, min_samples_split=7,
#                       random_state=17)  Test data  is 269.40045936853244

# %% [markdown]
# * GradientBoostingRegressor

# %%
gbdt1=GradientBoostingRegressor(loss='squared_error',learning_rate=0.1,criterion='friedman_mse',n_estimators=100,max_depth=19,min_samples_leaf=15,random_state=10)
gbdt1.fit(x_train,y_train)

Reg_eval(gbdt1,x_train,y_train,x_test,y_test,train=True)
Reg_eval(gbdt1,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for GradientBoostingRegressor(max_depth=19, min_samples_leaf=15, random_state=10)  for Train data  is 0.924772426701431
#
# The Root mean squared error for GradientBoostingRegressor(max_depth=19, min_samples_leaf=15, random_state=10)  for Train data is 132.83642963825613
#
# ********** Testing  Evaluation *******************
#
# The R squared for GradientBoostingRegressor(max_depth=19, min_samples_leaf=15, random_state=10)  for Test data is 0.765642074992673
#
# The Root mean squared error for GradientBoostingRegressor(max_depth=19, min_samples_leaf=15, random_state=10)  Test data  is 248.75632703464427

# %% [markdown]
# * Evaluation of estimators

# %%
regressors=[LinR1,SVR1,las1,rid1,gbdt1,xgr1,rf1,dt1]
Names=['Linear Regressor','SVRegressor','Lasso Regressor','Ridge Regressor','GBDTRegressor',
       'XGBRegressor',"RandomForestRegressor","DecisionTreeRegressor"]

# %%
scores_train= []
scores_test=[]
rmse_scores=[]
for reg in regressors:
    ypred_train=reg.predict(x_train)
    ypred_test=reg.predict(x_test)
    trainsc = r2_score(y_train,ypred_train)
    testsc=r2_score(y_test,ypred_test)
    rmse=np.sqrt(mean_squared_error(y_test,ypred_test))
    
    scores_train.append(trainsc)
    scores_test.append(testsc)
    rmse_scores.append(rmse)

# %% [markdown]
# * Selecting best CV parameter for cross validation

# %%
for i in [3,5,7,8,10]:
    cv=cross_val_score(LinearRegression(),x_dimR,y,cv=i,scoring='r2')
    print("R2 square is {0} for cv={1}".format(cv.mean(),i))
# Out:
# R2 square is 0.49892888936243246 for cv=3
# R2 square is 0.5156258936064999 for cv=5
# R2 square is 0.5181300675053192 for cv=7
# R2 square is 0.5308726922288971 for cv=8
# R2 square is 0.5321507424344276 for cv=10

# %% [markdown]
# * Generalized score obtained at cv=5

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores_mean=[]
cv_scores=[]
for reg in regressors:
    scr=cross_val_score(reg,x_dimR,y,cv=5,scoring="r2")
    cv_scores.append(scr)   
    cv_scores_mean.append(scr.mean())
cv_scores_mean
# Out:
# [0.5156258936064999,
#  0.6857581349907413,
#  0.5155848230041791,
#  0.515667712287739,
#  0.6973269035008072,
#  0.6549511346088739,
#  0.6984389229295566,
#  0.6532951075752774]

# %%
EvalDF=pd.DataFrame({'Regressor':Names,'Train R2 square':scores_train,'Test R2 square':scores_test,
                      'RMSE':rmse_scores,'Validation score':cv_scores_mean})

# %%
EvalDF["criteria of selecting best model"]=EvalDF['Test R2 square']-EvalDF['Validation score']

# %%
EvalDF.sort_values(by="criteria of selecting best model",ascending=True)
# Out:
#                Regressor  Train R2 square  Test R2 square        RMSE  \
# 6  RandomForestRegressor         0.733526        0.750608  256.611022
# 4          GBDTRegressor         0.924772        0.765642  248.756327
# 7  DecisionTreeRegressor         0.684330        0.725130  269.400459
# 1            SVRegressor         0.664743        0.765282  248.947200
# 5           XGBRegressor         0.965770        0.746371  258.781847
# 2        Lasso Regressor         0.508870        0.656072  301.347870
# 3        Ridge Regressor         0.508872        0.656171  301.304666
# 0       Linear Regressor         0.508872        0.656188  301.297140
#
#    Validation score  criteria of selecting best model
# 6          0.698439                          0.052169
# 4          0.697327                          0.068315
# 7          0.653295                          0.071834
# 1          0.685758                          0.079524
# 5          0.654951                          0.091420
# ...

# %% [markdown]
# * The best performance with least deviation from valiation score is obtained in RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
param2={'criterion' : ["squared_error", "absolute_error", "poisson"],
                   'max_depth' :[5,7,11,13],
                      'min_samples_split' :[15,17,18,19,20], 
                     'min_samples_leaf' :[10,11,14,18]}


grid2=GridSearchCV(RandomForestRegressor(bootstrap=True,oob_score=True,random_state=10),param_grid=param2,cv=5)
grid2.fit(x_train,y_train)  
print(grid2.best_params_)
# Out:
# {'criterion': 'poisson', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 15}

# %%
rf2=grid2.best_estimator_
rf2.fit(x_train,y_train)

Reg_eval(rf2,x_train,y_train,x_test,y_test,train=True)
Reg_eval(rf2,x_train,y_train,x_test,y_test,train=False)
# Out:
# ********** Training Evaluation *******************
#
# The R squared for RandomForestRegressor(criterion='poisson', max_depth=7, min_samples_leaf=10,
#                       min_samples_split=15, oob_score=True, random_state=10)  for Train data  is 0.7658343727422373
#
# The Root mean squared error for RandomForestRegressor(criterion='poisson', max_depth=7, min_samples_leaf=10,
#                       min_samples_split=15, oob_score=True, random_state=10)  for Train data is 234.3636434407799
#
# ********** Testing  Evaluation *******************
#
# The R squared for RandomForestRegressor(criterion='poisson', max_depth=7, min_samples_leaf=10,
#                       min_samples_split=15, oob_score=True, random_state=10)  for Test data is 0.7570091574326939
#
# The Root mean squared error for RandomForestRegressor(criterion='poisson', max_depth=7, min_samples_leaf=10,
#                       min_samples_split=15, oob_score=True, random_state=10)  Test data  is 253.29654564468825

# %% [markdown]
# * The Higher r2 score is achived with hyperparameter tunning of RandomForestClassifier rf2 with Hyperparameters
# criterion= poisson, max_depth=7, min_samples_leaf= 10, min_samples_split= 15
#
# 1] R2 score of test data is 0.7570
#
# 2] RMSE of 253.29

# %%
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse
prediction_test=rf2.predict(x_test)

# %%
print('Mean Absolute Error of prediction is ',mae(y_test,prediction_test))
# Out:
# Mean Absolute Error of prediction is  134.55271908397822

# %%
print('Mean Squared Error of prediction is ',mse(y_test,prediction_test))
# Out:
# Mean Squared Error of prediction is  64159.14003553164

# %% [markdown]
# * Plotting graph of prediction vs actual on scatterplot

# %%
Reg_plot(rf2,x_test,y_test)

# %% [markdown]
# * save model

# %%
import joblib

joblib.dump(rf2,'GppRF.pkl')
# Out:
# ['GppRF.pkl']

# %% [markdown]
# # Classifcation Task with primary fuel

# %% [markdown]
# * Dataframe for classification task

# %%
DATA=df.copy()

# %%
DATA.head()
# Out:
#    capacity_mw  primary_fuel  other_fuel1  generation_gwh_2014  \
# 0          2.5             6            0             0.000000
# 1         98.0             1            0             0.000000
# 2         39.2             7            0             0.000000
# 3        135.0             2            0           617.789264
# 4       1800.0             1            3          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                0.000             0.000000             0.000000
# 1                0.000             0.000000             0.000000
# 2                0.000             0.000000             0.000000
# 3              843.747           886.004428           663.774500
# 4             5916.370          6243.000000          5385.579736
#
#    generation_gwh_2018  sum_generation_gwh
# 0             0.000000            0.000000
# 1             0.000000            0.000000
# 2             0.000000            0.000000
# ...

# %%
DATA.shape
# Out:
# (687, 9)

# %% [markdown]
# * The label in classification is primary_fuel with  multiclass.

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 687 entries, 0 to 902
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          687 non-null    float64
#  1   primary_fuel         687 non-null    int32
#  2   other_fuel1          687 non-null    int32
#  3   generation_gwh_2014  687 non-null    float64
#  4   generation_gwh_2015  687 non-null    float64
#  5   generation_gwh_2016  687 non-null    float64
#  6   generation_gwh_2017  687 non-null    float64
#  7   generation_gwh_2018  687 non-null    float64
#  8   sum_generation_gwh   687 non-null    float64
# dtypes: float64(7), int32(2)
# memory usage: 64.5 KB

# %%
inf2=cont
inf2
# Out:
# ['capacity_mw',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'sum_generation_gwh']

# %% [markdown]
# * continuous feature in classification task

# %% [markdown]
# * Distribution of continuous features

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in inf2:
    if graph<=len(inf2):
        ax=plt.subplot(4,2,graph)
        sns.distplot(DATA[column],color='g')
        plt.xlabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * All feature are rightskewed due large amount of missing data which has imputed with 0

# %% [markdown]
# * Violin plot for continuous feature.

# %%
plt.figure(figsize=(20,35))
sns.set_palette('bright')
graph=1

for column in inf2:
    if graph<=7:
        ax=plt.subplot(4,2,graph)
        sns.violinplot(y=DATA[column])
        plt.ylabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * All variables are right skewed in nature with outliers at high side.

# %% [markdown]
# * Outlier detection with Boxplot

# %%
plt.figure(figsize=(20,35))
sns.set_palette('bright')
graph=1

for column in inf2:
    if graph<=7:
        ax=plt.subplot(4,2,graph)
        sns.boxplot(y=DATA[column])
        plt.ylabel(column,fontsize=15)
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * There large amount of missing data observed in continuous features.

# %% [markdown]
# * Analyse outliers removal and data loss

# %%
data=DATA.copy()
rows_before2=data.shape[0]
rows_before2
# Out:
# 687

# %%
from scipy.stats import zscore

z2=np.abs(zscore(data[inf2]))
data=data[(z2<3).all(axis=1)]

# %%
rows_after2=data.shape[0]
rows_after2
# Out:
# 666

# %%
loss2=((rows_before2-rows_after2)/rows_before2)*100
loss2
# Out:
# 3.056768558951965

# %% [markdown]
# * Data Loss after removal of outliers is 3.05 % so it can be safe to remove outliers with
#   z score method

# %% [markdown]
# * Analysis of Distribution of Before anf After Outlier treatment.

# %%
plt.figure(figsize=(20,40))
sns.set_palette('bright')
graph=1

for column in inf2:
    if graph<=len(inf2):
        ax=plt.subplot(4,2,graph)
        sns.kdeplot(DATA[column],color='red',shade=True)
        sns.kdeplot(data[column],color='green',shade=True)
        plt.xlabel(column,fontsize=20)
        plt.title("Distribution of {} Before and After Outlier treatment ".format(column))
        plt.legend(['Before  Outlier treatment','After  Outlier treatment'])
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Lets remove outliers with zscore

# %%
DATA.shape
# Out:
# (687, 9)

# %%
zscr2=np.abs(zscore(DATA[inf2]))
DATA=DATA[(zscr2<3).all(axis=1)]

# %%
DATA.shape
# Out:
# (666, 9)

# %% [markdown]
# * Correlation Analysis of variables

# %%
cor2=DATA.corr().abs()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor2,annot=True)
plt.title("Correlation Matrix for Classification")
plt.show()

# %% [markdown]
# 1] High correlation appears  within  yearly generation features.
#
# 2] capacity_mw has high correlation with other features.
#
# 3] other_fuel1 has correlation with other features in range of 0.3 to 0.4

# %% [markdown]
# * Correlation of feature with label primary_fuel

# %%
cor_label=(DATA.drop('primary_fuel',axis=1)).corrwith(DATA['primary_fuel']).abs()
cor_label
# Out:
# capacity_mw            0.391873
# other_fuel1            0.515422
# generation_gwh_2014    0.316083
# generation_gwh_2015    0.339862
# generation_gwh_2016    0.355227
# generation_gwh_2017    0.366328
# generation_gwh_2018    0.363142
# sum_generation_gwh     0.367164
# dtype: float64

# %%
plt.figure(figsize=(10,10))
cor_label.plot(kind="bar",color='lightgreen')
plt.title("Correlation with label primary_fuel")
plt.show()

# %% [markdown]
# 1] other_fuel1 has moderate correlation with priamry fuel
#
# 2] other all feature have correlation  lower than 0.4 with primary fuel.

# %% [markdown]
# * Analyse Multicollinearity with Variance Inflation Factor,Threshold for vif score is defined as 10 as data is less

# %%
from statsmodels.stats.outliers_influence  import variance_inflation_factor

FS1=DATA.drop(columns=['primary_fuel'],axis=1)
F1=FS1.to_numpy()

# %%
VIF21=pd.DataFrame()
VIF21["Features"]=FS1.columns
VIF21["vif_scores"]=[variance_inflation_factor(F1,i) for i in range(FS1.shape[1])]
VIF21
# Out:
#               Features  vif_scores
# 0          capacity_mw    5.229255
# 1          other_fuel1    2.232001
# 2  generation_gwh_2014         inf
# 3  generation_gwh_2015         inf
# 4  generation_gwh_2016         inf
# 5  generation_gwh_2017         inf
# 6  generation_gwh_2018         inf
# 7   sum_generation_gwh         inf

# %% [markdown]
# * Lets remove created feature with to analyse weather the infinite value multicollinearity due to calculated feature or not.

# %% [markdown]
# * Analysis of multicollinearity wit removal of sum_generation_gwh

# %%
FS2=DATA.drop(columns=['primary_fuel','sum_generation_gwh'],axis=1)
F2=FS2.to_numpy()
VIF22=pd.DataFrame()
VIF22["Features"]=FS2.columns
VIF22["vif_scores"]=[variance_inflation_factor(F2,i) for i in range(FS2.shape[1])]
VIF22
# Out:
#               Features  vif_scores
# 0          capacity_mw    5.229255
# 1          other_fuel1    2.232001
# 2  generation_gwh_2014   10.156800
# 3  generation_gwh_2015   21.723967
# 4  generation_gwh_2016   24.352892
# 5  generation_gwh_2017   32.243066
# 6  generation_gwh_2018   25.431441

# %% [markdown]
# * Analysis of multicollinearity wit removal of generation_gwh_2017

# %%
FS3=DATA.drop(columns=['primary_fuel','sum_generation_gwh','generation_gwh_2017'],axis=1)
F3=FS3.to_numpy()
VIF33=pd.DataFrame()
VIF33["Features"]=FS3.columns
VIF33["vif_scores"]=[variance_inflation_factor(F3,i) for i in range(FS3.shape[1])]
VIF33
# Out:
#               Features  vif_scores
# 0          capacity_mw    5.211003
# 1          other_fuel1    2.219937
# 2  generation_gwh_2014   10.147596
# 3  generation_gwh_2015   21.624406
# 4  generation_gwh_2016   20.231447
# 5  generation_gwh_2018   12.207169

# %% [markdown]
# * Analysis of multicollinearity wit removal of generation_gwh_2015

# %%
FS4=DATA.drop(columns=['primary_fuel','sum_generation_gwh','generation_gwh_2017','generation_gwh_2015'],axis=1)
F4=FS4.to_numpy()
VIF44=pd.DataFrame()
VIF44["Features"]=FS4.columns
VIF44["vif_scores"]=[variance_inflation_factor(F4,i) for i in range(FS4.shape[1])]
VIF44
# Out:
#               Features  vif_scores
# 0          capacity_mw    5.183000
# 1          other_fuel1    2.212270
# 2  generation_gwh_2014    4.127076
# 3  generation_gwh_2016   12.735116
# 4  generation_gwh_2018   12.014177

# %% [markdown]
# * Analysis of multicollinearity wit removal of generation_gwh_2016

# %%
FS5=DATA.drop(columns=['primary_fuel','sum_generation_gwh','generation_gwh_2017','generation_gwh_2015','generation_gwh_2016'],axis=1)
F5=FS5.to_numpy()
VIF55=pd.DataFrame()
VIF55["Features"]=FS5.columns
VIF55["vif_scores"]=[variance_inflation_factor(F5,i) for i in range(FS5.shape[1])]
VIF55
# Out:
#               Features  vif_scores
# 0          capacity_mw    5.163202
# 1          other_fuel1    2.209825
# 2  generation_gwh_2014    3.152256
# 3  generation_gwh_2018    6.226861

# %% [markdown]
# * Its required to remove  3 feature to remove multicollinearity in dataset. Also low correlation of feature with label primary fuel.

# %% [markdown]
# * Analysis of Skewness in continuous features

# %%
DATA[inf2].skew()
# Out:
# capacity_mw            1.700370
# generation_gwh_2014    2.400794
# generation_gwh_2015    2.252079
# generation_gwh_2016    2.182037
# generation_gwh_2017    2.065490
# generation_gwh_2018    2.152723
# sum_generation_gwh     2.066576
# dtype: float64

# %%
DATA[inf2].skew().plot.bar(color='brown')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1] All features have higher skewness in continuous feature.
#
# 2] capacity_mw has skewness of 1.70 which is lowest among all features.
#
# 3] Yearly  generation feature have skeweness more than 2.0

# %% [markdown]
# * Power Transformer to remove skewness from continuous feature which will causes better performance of algorithms.

# %%
from sklearn.preprocessing import PowerTransformer

power2=PowerTransformer(method='yeo-johnson')
DATA[inf2]=power2.fit_transform(DATA[inf2])

# %%
fig,axs=plt.subplots(1,2)
data[inf2].skew().plot.bar(ax=axs[0],color='pink',title='Before')
DATA[inf2].skew().plot.bar(ax=axs[1],color='lightgreen',title='After')
plt.yticks(np.arange(-0.5,2.5,0.5))
plt.show()

# %% [markdown]
# * Analysis of tranformation before and after transformation.

# %%
plt.figure(figsize=(20,30))
sns.set_palette('bright')
graph=1

for column in inf2:
    if graph<=len(inf2):
        ax=plt.subplot(4,2,graph)
        sns.distplot(data[column],color='red')
        sns.distplot(DATA[column],color='green')
        plt.xlabel(column,fontsize=20)
        plt.legend(['Before Transformation','After Transformation'])
        
    graph+=1
plt.show()
plt.tight_layout()

# %% [markdown]
# * Skewness and Dustribution of continuous feature with after transformation canbe observe in above graphs.

# %% [markdown]
# * Spliting dataset into feature and Label

# %%
x2=DATA.drop('primary_fuel',axis=1)
y2=DATA.primary_fuel

# %%
print('x2 shape is ',x2.shape)
print('y2 shape is ',y2.shape)
# Out:
# x2 shape is  (666, 8)
# y2 shape is  (666,)

# %% [markdown]
# * Standardization of features

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled2=scaler.fit_transform(x2)

# %%
x_scaled2.shape
# Out:
# (666, 8)

# %% [markdown]
# * PCA to handle low correlation of feature with label and high multicolllinearity among features

# %%
from sklearn.decomposition import PCA

pc=PCA()
pc.fit_transform(x_scaled2)
# Out:
# array([[-3.24827108, -0.23022395, -0.80587024, ...,  0.02185738,
#          0.04215632,  0.01157433],
#        [-2.63120598,  0.3142731 ,  0.52552959, ..., -0.06986015,
#         -0.12452936, -0.03250217],
#        [-2.80728453,  0.15890173,  0.14561676, ..., -0.0436887 ,
#         -0.07696587, -0.01992501],
#        ...,
#        [ 3.43836359,  0.71485991, -0.54551699, ...,  0.00783023,
#         -0.07048002, -0.02356758],
#        [-2.61455043,  0.32896993,  0.56146615, ..., -0.07233575,
#         -0.12902847, -0.03369186],
#        [ 1.26639228,  2.21388636,  1.32993434, ..., -0.36205235,
#          0.16226537,  0.05184291]])

# %%
plt.figure()
plt.plot(np.cumsum(pc.explained_variance_ratio_))
plt.xlabel('Components')
plt.ylabel('Variance Explained')
plt.title('PCA analysis classification task')
plt.xticks(range(0,8))
plt.show()

# %%
pd.Series(np.cumsum(pc.explained_variance_ratio_))
# Out:
# 0    0.815942
# 1    0.910593
# 2    0.949901
# 3    0.979076
# 4    0.989445
# 5    0.994496
# 6    0.997682
# 7    1.000000
# dtype: float64

# %% [markdown]
# * we will apply 6 components from PCA for model building

# %%
pc1=PCA(n_components=6)
dimC=pc1.fit_transform(x_scaled2)
x_dimC=pd.DataFrame(dimC,columns=[('PC{}').format(i) for i in range(1,7)])
x_dimC
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6
# 0   -3.248271 -0.230224 -0.805870 -0.557877  0.106428  0.021857
# 1   -2.631206  0.314273  0.525530  0.437339 -0.045614 -0.069860
# 2   -2.807285  0.158902  0.145617  0.153356 -0.002229 -0.043689
# 3    1.666349 -1.204988 -0.098931 -0.145616  0.108508 -0.031823
# 4    4.012886  0.849347  0.022481  0.245379 -0.022243  0.009636
# ..        ...       ...       ...       ...       ...       ...
# 661 -2.830192  0.138688  0.096191  0.116410  0.003415 -0.040284
# 662 -2.794387  0.170283  0.173446  0.174158 -0.005407 -0.045606
# 663  3.438364  0.714860 -0.545517  0.050031 -0.020012  0.007830
# 664 -2.614550  0.328970  0.561466  0.464201 -0.049718 -0.072336
# 665  1.266392  2.213886  1.329934 -0.715656 -0.240991 -0.362052
#
# [666 rows x 6 columns]

# %%
x_dimC.shape
# Out:
# (666, 6)

# %%
y2.shape
# Out:
# (666,)

# %% [markdown]
# * Analysing Imbalanced in data with label primary_fuel

# %%
y2.value_counts()
# Out:
# 1    216
# 3    211
# 7     84
# 2     68
# 6     34
# 0     26
# 5     18
# 4      9
# Name: primary_fuel, dtype: int64

# %%
y2.value_counts().plot.pie(autopct='%0.00f%%')
# Out:
# <AxesSubplot:ylabel='primary_fuel'>

# %%
y2.value_counts().plot.bar(color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * There is imbalanced observed in data which can be handle with SMOTE with oversampling

# %% [markdown]
# * Oversampling

# %%
from imblearn.over_sampling import SMOTE

sm=SMOTE(k_neighbors=3,random_state=46)
X,Y=sm.fit_resample(x_dimC,y2)

# %%
print('X shape is ',X.shape)
print('Y shape is ',Y.shape)
# Out:
# X shape is  (1728, 6)
# Y shape is  (1728,)

# %%
Y.value_counts()
# Out:
# 6    216
# 1    216
# 7    216
# 2    216
# 3    216
# 0    216
# 5    216
# 4    216
# Name: primary_fuel, dtype: int64

# %% [markdown]
# * The Imbalanced in data has been removed with oversamplling with SMOTE

# %% [markdown]
# * Training phase

# %%
from sklearn.neighbors import KNeighborsClassifier


from sklearn.svm import SVC

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier


from xgboost import XGBClassifier

from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import roc_curve,roc_auc_score,classification_report,confusion_matrix,plot_roc_curve

from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score

from sklearn.model_selection import train_test_split

# %%
maxac=0
maxRs=0
for i  in range(1,200):
    xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.25,random_state=i)
    clf=DecisionTreeClassifier()
    clf.fit(xtrain,ytrain)
    ypred=clf.predict(xtest)
    acc=accuracy_score(ytest,ypred)
    print("acuracy score ",acc,'Random sate ',i)
    
    if acc>maxac:
        maxac=acc
        maxRs=i
        print("Accuracy",maxac,"random_state",i)
# Out:
# acuracy score  0.5925925925925926 Random sate  1
# Accuracy 0.5925925925925926 random_state 1
# acuracy score  0.5972222222222222 Random sate  2
# Accuracy 0.5972222222222222 random_state 2
# acuracy score  0.6180555555555556 Random sate  3
# Accuracy 0.6180555555555556 random_state 3
# acuracy score  0.5833333333333334 Random sate  4
# acuracy score  0.6041666666666666 Random sate  5
# acuracy score  0.6041666666666666 Random sate  6
# acuracy score  0.5925925925925926 Random sate  7
# acuracy score  0.5833333333333334 Random sate  8
# acuracy score  0.5995370370370371 Random sate  9
# acuracy score  0.5787037037037037 Random sate  10
# acuracy score  0.6134259259259259 Random sate  11
# acuracy score  0.5625 Random sate  12
# acuracy score  0.5949074074074074 Random sate  13
# acuracy score  0.6064814814814815 Random sate  14
# acuracy score  0.5324074074074074 Random sate  15
# acuracy score  0.5717592592592593 Random sate  16
# acuracy score  0.5995370370370371 Random sate  17
# ...

# %%
print("Maximum accuracy Score is {0} and Random state is {1}".format(maxac,maxRs))
# Out:
# Maximum accuracy Score is 0.6666666666666666 and Random state is 151

# %% [markdown]
# * Train Test Split data

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.25,random_state=151)

# %% [markdown]
# * Score function for multiclass task

# %%
def Cscore(clf,x_trn,y_trn,x_tst,y_tst,train_score=True):
    if train_score:
        ypred_train=clf.predict(x_trn)
        print('******** Train Results***************')
        print("Train Accuracy Score is ",accuracy_score(y_trn,ypred_train))
        print('******************************************************')
       
        
    elif train_score==False:
        ypred_test=clf.predict(x_tst)
        ypred_pro=clf.predict_proba(x_tst)
        print('\n******** Test Results***************')
        print("Test Accuracy Score is ", accuracy_score(y_tst,ypred_test))
        print('******************************************************')
        print("Test Precision Score is ", precision_score(y_tst,ypred_test,average='macro'))
        print('******************************************************')
        print("Test f1 Score is ", f1_score(y_tst,ypred_test,average='macro'))
        print('******************************************************')
        print("Test Recall Score is ", recall_score(y_tst,ypred_test,average='macro'))
        print('******************************************************')
        print("Test roc auc Score is ", roc_auc_score(y_tst,ypred_pro,multi_class='ovr'))
        print('******************************************************')
        print('\n Classification Report \n ',classification_report(y_tst,ypred_test,digits=3))

# %% [markdown]
# * Decision TreeClassifier

# %%
DT1=DecisionTreeClassifier(criterion='entropy',max_depth=18,min_samples_split=3,min_samples_leaf=1,random_state=156)
DT1.fit(xtrain,ytrain)

Cscore(DT1,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(DT1,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.9004629629629629
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6643518518518519
# ******************************************************
# Test Precision Score is  0.6689098347417533
# ******************************************************
# Test f1 Score is  0.6572545829545187
# ******************************************************
# Test Recall Score is  0.6590363684552613
# ******************************************************
# Test roc auc Score is  0.823649902427834
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.492     0.615     0.547        52
#            1      0.722     0.750     0.736        52
#            2      0.516     0.604     0.557        53
#            3      0.754     0.741     0.748        58
# ...

# %% [markdown]
# * RandomForestClassifier

# %%
RF1=RandomForestClassifier(max_depth=12,min_samples_split=7,min_samples_leaf=5,bootstrap=True,oob_score=True,random_state=178)
RF1.fit(xtrain,ytrain)

Cscore(RF1,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(RF1,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.7762345679012346
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6805555555555556
# ******************************************************
# Test Precision Score is  0.6842815941754106
# ******************************************************
# Test f1 Score is  0.6732754013389973
# ******************************************************
# Test Recall Score is  0.6754756274997195
# ******************************************************
# Test roc auc Score is  0.9366961433539134
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.532     0.635     0.579        52
#            1      0.891     0.788     0.837        52
#            2      0.697     0.434     0.535        53
#            3      0.800     0.759     0.779        58
# ...

# %% [markdown]
# * KNeighborsClassifier

# %%
KNN1=KNeighborsClassifier(n_neighbors=5,leaf_size=30,algorithm='auto',weights='uniform')
KNN1.fit(xtrain,ytrain)

Cscore(KNN1,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(KNN1,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.7415123456790124
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6851851851851852
# ******************************************************
# Test Precision Score is  0.6856879857278202
# ******************************************************
# Test f1 Score is  0.6792096767847136
# ******************************************************
# Test Recall Score is  0.6812727946669161
# ******************************************************
# Test roc auc Score is  0.8966103802795468
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.545     0.692     0.610        52
#            1      0.840     0.808     0.824        52
#            2      0.592     0.547     0.569        53
#            3      0.848     0.672     0.750        58
# ...

# %% [markdown]
# * GradientBoostingClassifier

# %%
GBDT1=GradientBoostingClassifier(learning_rate=0.15,max_depth=21,min_samples_leaf=50,random_state=95)
GBDT1.fit(xtrain,ytrain)

Cscore(GBDT1,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(GBDT1,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.8873456790123457
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6666666666666666
# ******************************************************
# Test Precision Score is  0.6647219314379682
# ******************************************************
# Test f1 Score is  0.6591233617805512
# ******************************************************
# Test Recall Score is  0.6604774944694192
# ******************************************************
# Test roc auc Score is  0.9396601438833821
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.517     0.596     0.554        52
#            1      0.830     0.750     0.788        52
#            2      0.543     0.472     0.505        53
#            3      0.786     0.759     0.772        58
# ...

# %% [markdown]
# * XGBCLassifier

# %%
XGC1=XGBClassifier(learning_rate=0.18,random_state=24,booster='gbtree')
XGC1.fit(xtrain,ytrain)

Cscore(XGC1,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(XGC1,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.8842592592592593
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6828703703703703
# ******************************************************
# Test Precision Score is  0.6882686907077362
# ******************************************************
# Test f1 Score is  0.6785466748089277
# ******************************************************
# Test Recall Score is  0.677335008972031
# ******************************************************
# Test roc auc Score is  0.9415866675202959
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.492     0.577     0.531        52
#            1      0.929     0.750     0.830        52
#            2      0.644     0.547     0.592        53
#            3      0.786     0.759     0.772        58
# ...

# %% [markdown]
# * SElecting best cv parameter.

# %%
from sklearn.model_selection import cross_val_score


for i in [3,5,7,8,9,10]:
    cv=cross_val_score(DecisionTreeClassifier(random_state=121),X,Y,cv=i,scoring='accuracy')
    print("Accuracy score is {0} for cv={1}".format(cv.mean(),i))
# Out:
# Accuracy score is 0.6226851851851852 for cv=3
# Accuracy score is 0.6198224009382591 for cv=5
# Accuracy score is 0.610550767161807 for cv=7
# Accuracy score is 0.6076388888888888 for cv=8
# Accuracy score is 0.6024305555555556 for cv=9
# Accuracy score is 0.6007259040193574 for cv=10

# %% [markdown]
# *Best cv for most generalized score is cv=10

# %%
classifiers =[KNN1,GBDT1,DT1,RF1,XGC1]
name=['KNeighborsClassifier','GradientBoostClassifier',
      'DecisionTreeClassifier','RandomForestClassifier','XGBoostClassifier']

# %%
test_score=[]
ra_score=[]
train_score=[]
for i in classifiers:
    ypred_test=i.predict(xtest)
    y_pred_pro=i.predict_proba(xtest)
    ypred_train=i.predict(xtrain)
    test_score.append(accuracy_score(ytest,ypred_test))
    ra_score.append(roc_auc_score(ytest,y_pred_pro,multi_class='ovr'))
    train_score.append(accuracy_score(ytrain,ypred_train))

# %%
cv_scores_mean=[]
cv_scores=[]
for clf in classifiers:
    scr=cross_val_score(clf,X,Y,cv=10,scoring="accuracy")
    cv_scores.append(scr)   
    cv_scores_mean.append(scr.mean())
cv_scores_mean
# Out:
# [0.6539655867724157,
#  0.6493312273154993,
#  0.6076858448716226,
#  0.6626327463368733,
#  0.6475836806022315]

# %%
Eval_clf=pd.DataFrame({'Classifier':name,'Train Accuracy Score':train_score,'Test Accuracy Score':test_score,
                      'ROC_AUC_Score':ra_score,'Validation Score':cv_scores_mean})

# %%
Eval_clf["criteria of selecting best model"]=Eval_clf['Test Accuracy Score']-Eval_clf['Validation Score']

# %%
Eval_clf.sort_values(by="criteria of selecting best model",ascending=True)
# Out:
#                 Classifier  Train Accuracy Score  Test Accuracy Score  \
# 1  GradientBoostClassifier              0.887346             0.666667
# 3   RandomForestClassifier              0.776235             0.680556
# 0     KNeighborsClassifier              0.741512             0.685185
# 4        XGBoostClassifier              0.884259             0.682870
# 2   DecisionTreeClassifier              0.900463             0.664352
#
#    ROC_AUC_Score  Validation Score  criteria of selecting best model
# 1       0.939660          0.649331                          0.017335
# 3       0.936696          0.662633                          0.017923
# 0       0.896610          0.653966                          0.031220
# 4       0.941587          0.647584                          0.035287
# 2       0.823650          0.607686                          0.056666

# %% [markdown]
# * From above analysis and score,we will perform hyperparameter tunning on GBDTClassifeir and RandomForest with GridSearchCV having least deviations in Test score and Validation score.

# %% [markdown]
# * Hyper Parameter tunning with GradientBoostingClassifier.

# %%
from sklearn.model_selection import GridSearchCV

# %%
p1={'n_estimators':[50,100],
         'min_samples_leaf':[40,50,60,70],
            'max_depth':[12,15,21,25],
           'learning_rate':[0.1,0.15,0.20,0.25]}


search1=GridSearchCV(GradientBoostingClassifier(random_state=95),cv=5,param_grid=p1)
search1.fit(xtrain,ytrain)
print(search1.best_params_)
# Out:
# {'learning_rate': 0.25, 'max_depth': 12, 'min_samples_leaf': 70, 'n_estimators': 50}

# %%
GB2=search1.best_estimator_
GB2.fit(xtrain,ytrain)

Cscore(GB2,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(GB2,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.8526234567901234
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6759259259259259
# ******************************************************
# Test Precision Score is  0.6751305001785108
# ******************************************************
# Test f1 Score is  0.6693002621811195
# ******************************************************
# Test Recall Score is  0.670368586949541
# ******************************************************
# Test roc auc Score is  0.9407505276108052
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.516     0.615     0.561        52
#            1      0.867     0.750     0.804        52
#            2      0.600     0.509     0.551        53
#            3      0.811     0.741     0.775        58
# ...

# %% [markdown]
# * Hyperparameter tunning with  RandomForestClassifeir

# %%
p2={'criterion' : ['gini','entropy','log_loss'],
                     'max_depth' :[9,10,12,13],
                      'min_samples_split' :[3,5,7,9], 
                     'min_samples_leaf' :[3,5,6,7]   }


search2=GridSearchCV(RandomForestClassifier(bootstrap=True,oob_score=True,random_state=178),param_grid=p2,cv=5).fit(xtrain,ytrain) 
print(search2.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 3}

# %%
RF2=search1.best_estimator_
RF2.fit(xtrain,ytrain)

Cscore(RF2,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(RF2,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.8526234567901234
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6759259259259259
# ******************************************************
# Test Precision Score is  0.6751305001785108
# ******************************************************
# Test f1 Score is  0.6693002621811195
# ******************************************************
# Test Recall Score is  0.670368586949541
# ******************************************************
# Test roc auc Score is  0.9407505276108052
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.516     0.615     0.561        52
#            1      0.867     0.750     0.804        52
#            2      0.600     0.509     0.551        53
#            3      0.811     0.741     0.775        58
# ...

# %% [markdown]
# # Finalizing Model

# %% [markdown]
# 1] The best Accuracy obtained with GB2 which is  GradientBossting Classifier with least deviation from in Test Score and Validation Score with parameters as 'learning_rate': 0.25, 'max_depth': 12, 'min_samples_leaf': 70, 'n_estimators': 50.
#
# 2] Test Accuracy Score of 0.6759
#
# 3] Test roc auc Score is  0.940

# %%
Cscore(GB2,xtrain,ytrain,xtest,ytest,train_score=True)
Cscore(GB2,xtrain,ytrain,xtest,ytest,train_score=False)
# Out:
# ******** Train Results***************
# Train Accuracy Score is  0.8526234567901234
# ******************************************************
#
# ******** Test Results***************
# Test Accuracy Score is  0.6759259259259259
# ******************************************************
# Test Precision Score is  0.6751305001785108
# ******************************************************
# Test f1 Score is  0.6693002621811195
# ******************************************************
# Test Recall Score is  0.670368586949541
# ******************************************************
# Test roc auc Score is  0.9407505276108052
# ******************************************************
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0      0.516     0.615     0.561        52
#            1      0.867     0.750     0.804        52
#            2      0.600     0.509     0.551        53
#            3      0.811     0.741     0.775        58
# ...

# %% [markdown]
# * AUC curve for GradientBoostingClassifier

# %%
y_pred = GB2.predict(xtest)
y_prob_pred = GB2.predict_proba(xtest)

#roc auc score
roc_auc_score(ytest, y_prob_pred, multi_class='ovr', average='macro')

fpr = {}
tpr = {}
thresh ={}

classes = len(Y.unique())

for i in range(classes):    
    fpr[i], tpr[i], thresh[i] = roc_curve(ytest, y_prob_pred[:,i], pos_label=i)
colors=['r','blue','black','green','purple','skyblue','orange','m'] 
plt.figure(figsize=(20,20))
for i,color in  zip(range(classes),colors):
    plt.plot(fpr[i], tpr[i],color=color,label='Class {} vs Rest'.format(i))
plt.title('roc auc curve for GradientBoostingClassifier')
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# * Save  Model

# %%
import joblib

joblib.dump(GB2,'GPPclf.pkl')
# Out:
# ['GPPclf.pkl']
